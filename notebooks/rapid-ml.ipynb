# %%
import numpy as np
import statsmodels.api as smf
import pandas as pd

# %%
df = pd.read_csv('../data/fraud_synthetic_data.csv')
df
# Out:
#            age  years_in_labour_force  years_of_further_education  \
# 0    25.971259              14.809051                    8.307270
# 1    34.934750              15.535064                    3.930498
# 2    27.245978              21.471393                    4.623026
# 3    49.167824              20.404425                    4.177440
# 4    37.291319              21.469093                    3.656979
# ..         ...                    ...                         ...
# 295  35.212400              15.984310                    3.769215
# 296  48.284889              21.750693                    7.106139
# 297  55.678414              21.991916                    5.296406
# 298  36.013001              21.105715                    3.594546
# 299  33.965073              10.195793                    5.035284
#
#      miles_resided_from_coast  committed
# 0                   55.530100          0
# 1                   44.099918          0
# 2                   50.431172          0
# 3                   69.176778          0
# 4                   52.866486          0
# ..                        ...        ...
# 295                 56.607121          0
# 296                 49.705433          0
# 297                 58.287349          0
# 298                 53.358712          0
# 299                 70.462106          0
#
# [300 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, random_state=42)

# %%
train.corr()
# Out:
#                                  age  years_in_labour_force  \
# age                         1.000000               0.825626
# years_in_labour_force       0.825626               1.000000
# years_of_further_education -0.093829              -0.089592
# miles_resided_from_coast   -0.086484              -0.109925
# committed                   0.217829               0.171537
#
#                             years_of_further_education  \
# age                                          -0.093829
# years_in_labour_force                        -0.089592
# years_of_further_education                    1.000000
# miles_resided_from_coast                     -0.049376
# committed                                     0.100644
#
#                             miles_resided_from_coast  committed
# age                                        -0.086484   0.217829
# years_in_labour_force                      -0.109925   0.171537
# years_of_further_education                 -0.049376   0.100644
# miles_resided_from_coast                    1.000000  -0.030400
# committed                                  -0.030400   1.000000

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

mod = smf.ols(formula='committed ~ age + years_in_labour_force + years_of_further_education+ miles_resided_from_coast', data=train)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              committed   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     3.661
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):            0.00656
# Time:                        16:18:13   Log-Likelihood:                -72.346
# No. Observations:                 225   AIC:                             154.7
# Df Residuals:                     220   BIC:                             171.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.2635      0.145     -1.820      0.070      -0.549       0.022
# age                            0.0081      0.004      2.134      0.034       0.001       0.016
# years_in_labour_force         -0.0014      0.007     -0.191      0.849      -0.016       0.013
# years_of_further_education     0.0210      0.011      1.850      0.066      -0.001       0.043
# miles_resided_from_coast      -0.0001      0.001     -0.083      0.934      -0.003       0.003
# ==============================================================================
# Omnibus:                       81.280   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              166.740
# Skew:                           1.867   Prob(JB):                     6.21e-37
# Kurtosis:                       4.960   Cond. No.                         455.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
